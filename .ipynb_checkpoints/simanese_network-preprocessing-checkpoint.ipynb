# %%
from tensorflow.keras.models import load_model
from VisionUtils import *
from imgaug import augmenters as iaa
from Manager import *
import tensorflow.keras.backend as k
import tensorflow as tf

import matplotlib.pyplot as plt
import os 
import imgaug
import shutil
import tqdm
tf.enable_eager_execution()
tf.__version__
# Out:
# '1.14.0'

# %%
m = load_model("Models/FaceNet/model/saved_model.h5")
face_detector =MTCNN()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0915 01:02:49.588751 17892 hdf5_format.py:221] No training configuration found in save file: the model was *not* compiled. Compile it manually.
# W0915 01:02:49.600691 17892 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\mtcnn.py:187: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0915 01:02:49.602357 17892 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\mtcnn.py:193: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0915 01:02:49.626215 17892 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\network.py:43: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0915 01:02:49.626931 17892 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:88: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0915 01:02:49.629914 17892 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:79: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0915 01:02:49.631106 17892 deprecation.py:506] From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0915 01:02:49.657646 17892 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:171: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0915 01:02:49.721744 17892 deprecation.py:323] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:221: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0915 01:02:49.940896 17892 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:196: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.

# %%
### Important Dirrectories
IMG_RT_PATH = 'data/images2/'
PROCESSED_IMG_RT_PATH = 'data/processed2/images2/'
FEATURE_RT_PATH = "data/image_features/"
FEATURE_AUG_RT_PATH = "data/image_aug_features/"
IMG_AUG_RT_PATH = 'data/images_aug/'

# %%
input_shape = (160, 160, 3)

# %%
import pathlib
data_root = pathlib.Path(IMG_RT_PATH)
print('data_root: ', data_root)
# Out:
# data_root:  data\images2

# %%
for item_path in data_root.iterdir():
    print('item_path: ', item_path)
# Out:
# item_path:  data\images2\n000001
# item_path:  data\images2\n000002
# item_path:  data\images2\n000003
# item_path:  data\images2\n000004
# item_path:  data\images2\n000006
# item_path:  data\images2\n000007
# item_path:  data\images2\n000008
# item_path:  data\images2\n000009
# item_path:  data\images2\n000010
# item_path:  data\images2\n000012
# item_path:  data\images2\n000013
# item_path:  data\images2\n000015
# item_path:  data\images2\n000016
# item_path:  data\images2\n000017
# item_path:  data\images2\n000018
# item_path:  data\images2\n000019
# item_path:  data\images2\n000020
# item_path:  data\images2\n000029
# item_path:  data\images2\n000032
# item_path:  data\images2\n000037
# item_path:  data\images2\n000040
# item_path:  data\images2\n000045
# item_path:  data\images2\n000046
# item_path:  data\images2\n000056
# item_path:  data\images2\n000065
# item_path:  data\images2\n000070
# item_path:  data\images2\n000074
# item_path:  data\images2\n000076
# item_path:  data\images2\n000078
# item_path:  data\images2\n000079
# item_path:  data\images2\n000082
# item_path:  data\images2\n000084
# item_path:  data\images2\n000088
# item_path:  data\images2\n000094
# item_path:  data\images2\n000096
# item_path:  data\images2\n000104
# item_path:  data\images2\n000106
# item_path:  data\images2\n000114
# item_path:  data\images2\n000118
# item_path:  data\images2\n000119
# item_path:  data\images2\n000127
# item_path:  data\images2\n000129
# item_path:  data\images2\n000130
# item_path:  data\images2\n000135
# item_path:  data\images2\n000144
# item_path:  data\images2\n000148
# item_path:  data\images2\n009028
# item_path:  data\images2\n009114
# item_path:  data\images2\n009123
# item_path:  data\images2\n009175
# item_path:  data\images2\n009185
# item_path:  data\images2\n009199
# item_path:  data\images2\n009213
# item_path:  data\images2\n009225
# item_path:  data\images2\n009232
# item_path:  data\images2\n009235
# item_path:  data\images2\n009283
# item_path:  data\images2\n009285
# item_path:  data\images2\n009286
# item_path:  data\images2\n009287
# item_path:  data\images2\n009288
# item_path:  data\images2\n009289
# item_path:  data\images2\n009291
# item_path:  data\images2\n009294

# %%
import random 
import pathlib

data_root = pathlib.Path(IMG_RT_PATH)
print('data_root: ', data_root)
all_image_paths = list(data_root.glob('*/*'))
all_image_paths = [ str(path) for path in all_image_paths ]
random.shuffle(all_image_paths)
image_count = len(all_image_paths)
image_count
# Out:
# data_root:  data\images2
# 198312

# %%
def crop_face(img, bb):
    """
    Crop image given bounding box (x,y, width, height)
    """
    x1, y1, width, height = bb
    x1,y1 = abs(x1), abs(y1)
    x2, y2 = x1 + width, y1 +height
    return img[y1:y2, x1:x2]

# %%
def detect_faces(img, detector):
    results = detector.detect_faces(img)
    bb_lst =[]
    for i in results:
        bb_lst.append(i["box"])
    return bb_lst

# %%
def preprocess_image(image):
    
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [600, 600])
#     image /= 255.0 

    return image

# %%
def load_and_preprocess_image(path):
    image = tf.read_file(path)
    return preprocess_image(image)

# %%
import os, random
#random.choice(os.listdir("data/images/n000476"))

# %%
import os, random
random_dir = random.choice(os.listdir("data/images2"))
random_file = random.choice(os.listdir("data/images2/"+random_dir))
random_file
# Out:
# '0130_03.jpg'

# %%
def load_positive_match(label_index):
    label = index_to_label[label_index]
    dir_path = 'data/images2/'+label
    img_path1 = dir_path+'/'+random.choice(os.listdir(dir_path))
    image = load_and_preprocess_image2(img_path1)
    return image

# %%
import shutil

def load_random_match():
    dirs = os.listdir("data/images2")
    if len(dirs) != 0:
        random_dir = random.choice(dirs)
        dir_files = os.listdir("data/images2/"+random_dir)
        while len(dir_files) == 0:
            empty_dir = "data/images2/"+random_dir
            #print('removing empty_dir: ', empty_dir)
            shutil.rmtree("data/images2/"+random_dir)
            dirs = os.listdir("data/images2")
            random_dir = random.choice(dirs)
            dir_files = os.listdir("data/images2/"+random_dir)
        if len(dir_files) != 0:
            random_file = random.choice(dir_files)
            while '.jpg' not in random_file:
                #print('redo random.choice(dir_files) : ', random_dir)
                random_file = random.choice(dir_files)
            image = load_and_preprocess_image2("data/images2/"+random_dir+'/'+random_file)
            return random_dir, image
        else:
            return '', None

    else:
        #print('dirs: ', dirs)
        return '', None

# %%
# import random 
# import pathlib

# data_root = pathlib.Path(IMG_RT_PATH)
# print('data_root: ', data_root)
# all_image_paths = list(data_root.glob('*/*'))
# all_image_paths = [ str(path) for path in all_image_paths ]


all_image_paths[0]
# Out:
# 'data\\images2\\n002763\\0198_01.jpg'

# %%
pth = all_image_paths[0]
'/'.join(pth.split('/')[:-1])
# pth.split('/')[-1]
# Out:
# ''

# %%
PROCESSED_IMG_RT_PATH
# Out:
# 'data/processed2/images2/'

# %%
for image_path in all_image_paths:
    root = '/'.join(image_path.split('/')[:-1])
    image_name = image_path.split('\\')[-1]
    directory = image_path.split('\\')[-2:-1][0]
    
    if(not os.path.isdir(PROCESSED_IMG_RT_PATH+directory)):
        os.mkdir(PROCESSED_IMG_RT_PATH+directory)
    
    if(os.path.isfile(image_path)):
        image = plt.imread(image_path)
    else: continue
    bb = detect_faces(image, face_detector)
    if (len(bb)!=1):
        continue
    image = crop_face( normalize(image), bb[0])
    image = cv2.resize(image,(input_shape[0],input_shape[1]))
    plt.imsave(PROCESSED_IMG_RT_PATH+directory+'/'+image_name, image)

# %%
image_name

# %%
PROCESSED_IMG_RT_PATH+directory+'/'+image_name

# %%
image
# Out:
# array([[[0.04276961, 0.0310049 , 0.01139706],
#         [0.04980392, 0.03803922, 0.01843137],
#         [0.05416475, 0.04240005, 0.0227922 ],
#         ...,
#         [0.18212125, 0.15527918, 0.13040173],
#         [0.19472809, 0.16727711, 0.13590456],
#         [0.20110294, 0.17365196, 0.14227941]],
#
#        [[0.04142157, 0.02965686, 0.01004902],
#         [0.04746668, 0.03570198, 0.01609413],
#         [0.05465686, 0.04289216, 0.02328431],
#         ...,
#         [0.17906518, 0.158678  , 0.13361098],
#         [0.20560202, 0.18111864, 0.14875689],
#         [0.20955882, 0.18210784, 0.15073529]],
#
#        [[0.04889706, 0.03713235, 0.01752451],
#         [0.05406288, 0.04229818, 0.02269033],
#         [0.05962967, 0.04786497, 0.02825712],
#         ...,
#         [0.16872702, 0.1497932 , 0.12424173],
#         [0.18579733, 0.16946653, 0.13438725],
#         [0.19656863, 0.17463235, 0.14142157]],
#
#        ...,
#
#        [[0.05098039, 0.04705882, 0.03137255],
#         [0.03878025, 0.03485869, 0.01917241],
#         [0.03737745, 0.03345588, 0.01776961],
#         ...,
#         [0.16065219, 0.1214365 , 0.11751494],
#         [0.12057598, 0.08136029, 0.07743873],
#         [0.09595588, 0.0567402 , 0.05281863]],
#
#        [[0.05098039, 0.04705882, 0.03137255],
#         [0.04295688, 0.03903531, 0.02334903],
#         [0.04203431, 0.03811275, 0.02242647],
#         ...,
#         [0.14465188, 0.1054362 , 0.10151463],
#         [0.11339116, 0.07417547, 0.07025391],
#         [0.09129902, 0.05208333, 0.04816176]],
#
#        [[0.05453431, 0.05061275, 0.03492647],
#         [0.05068742, 0.04676585, 0.03107958],
#         [0.05318819, 0.04926662, 0.03358035],
#         ...,
#         [0.1243796 , 0.08516391, 0.08124234],
#         [0.10847809, 0.06926241, 0.06534084],
#         [0.09375   , 0.05453431, 0.05061275]]])

# %%
'done'

# %%
import tqdm

# %%
dataset = tf.data.Dataset.from_tensor_slices((data, labels))
dataset = dataset.batch(32).repeat()

val_dataset = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
val_dataset = val_dataset.batch(32).repeat()

callbacks = [
  # Interrupt training if `val_loss` stops improving for over 2 epochs
  tf.keras.callbacks.EarlyStopping(patience=2, monitor='val_loss'),
  # Write TensorBoard logs to `./logs` directory
  tf.keras.callbacks.TensorBoard(log_dir='./logs')
]
model.fit(data, labels, batch_size=32, epochs=5, callbacks=callbacks,
          validation_data=(val_data, val_labels))
