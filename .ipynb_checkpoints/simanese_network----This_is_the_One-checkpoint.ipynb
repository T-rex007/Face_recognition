# %%
from tensorflow.keras.models import load_model
from VisionUtils import *
#from imgaug import augmenters as iaa
from Manager import *
from sklearn.model_selection import train_test_split

import tensorflow.keras.backend as k
import tensorflow as tf
import matplotlib.pyplot as plt
import os 
#import imgaug
import shutil
import tqdm
tf.enable_eager_execution()
tf.__version__
# Out:
# '1.13.1'

# %%
print(tf.test.is_gpu_available())
# Out:
# True

# %%
# tf.data api batch_size
BATCH_SIZE = 32

# %%
m = load_model("Models/FaceNet/model/saved_model.h5")
# Out:
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:642: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
### Important Dirrectories
IMG_RT_PATH = 'data/processed2/images2/'
FEATURE_RT_PATH = "data/image_features/"
FEATURE_AUG_RT_PATH = "data/image_aug_features/"
IMG_AUG_RT_PATH = 'data/images_aug/'

# %%
import pathlib
data_root = pathlib.Path(IMG_RT_PATH)
print('data_root: ', data_root)
# Out:
# data_root:  data\processed2\images2

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
all_dir_paths = [str(item_path) for item_path in data_root.iterdir() if '.DS_Store' not in str(item_path)]
all_dir_paths[:5]
# Out:
# ['data\\processed2\\images2\\n000001',
#  'data\\processed2\\images2\\n000002',
#  'data\\processed2\\images2\\n000003',
#  'data\\processed2\\images2\\n000004',
#  'data\\processed2\\images2\\n000006']

# %%
len(all_dir_paths)
# Out:
# 589

# %%
image_dir_paths_train, image_dir_paths_test, = train_test_split(all_dir_paths, test_size=0.2, shuffle=False)

# %%
len(image_dir_paths_train), image_dir_paths_train[0]
# Out:
# (471, 'data\\processed2\\images2\\n000001')

# %%
len(image_dir_paths_test), image_dir_paths_test[0]
# Out:
# (118, 'data\\processed2\\images2\\n006626')

# %%
all_train_image_paths = []
for image_dir_train_path in tqdm.tqdm(image_dir_paths_train[:606]):
    root = pathlib.Path(image_dir_train_path)
    train_image_paths = list(root.glob('*.jpg'))
    train_image_paths = [ str(item_path) for item_path in train_image_paths if '.DS_Store' not in str(item_path)]
    all_train_image_paths += train_image_paths

random.shuffle(all_train_image_paths)
train_image_count = len(all_train_image_paths)
train_image_count, all_train_image_paths[0]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 471/471 [00:00<00:00, 731.44it/s]
# (149186, 'data\\processed2\\images2\\n003513\\0286_01.jpg')

# %%
all_test_image_paths = []
for image_dir_test_path in tqdm.tqdm(image_dir_paths_test[:100]):
    root = pathlib.Path(image_dir_test_path)
    test_image_paths = list(root.glob('*.jpg'))
    test_image_paths = [ str(item_path) for item_path in test_image_paths if '.DS_Store' not in str(item_path)]
    all_test_image_paths += test_image_paths

random.shuffle(all_test_image_paths)
test_image_count = len(all_test_image_paths)
test_image_count, all_test_image_paths[0]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 795.57it/s]
# (30030, 'data\\processed2\\images2\\n008436\\0197_01.jpg')

# %%
label_names = sorted(item.name for item in data_root.glob('*/') if item.is_dir())
label_names
# Out:
# ['n000001',
#  'n000002',
#  'n000003',
#  'n000004',
#  'n000006',
#  'n000007',
#  'n000008',
#  'n000009',
#  'n000010',
#  'n000012',
#  'n000013',
#  'n000015',
#  'n000016',
#  'n000017',
#  'n000018',
#  'n000019',
#  'n000020',
#  'n000029',
#  'n000032',
#  'n000037',
#  'n000040',
#  'n000045',
#  'n000046',
#  'n000056',
#  'n000065',
#  'n000070',
#  'n000074',
#  'n000076',
#  'n000078',
#  'n000079',
#  'n000082',
#  'n000084',
#  'n000088',
#  'n000094',
#  'n000096',
#  'n000104',
#  'n000106',
#  'n000114',
#  'n000118',
#  'n000119',
#  'n000127',
#  'n000129',
#  'n000130',
#  'n000135',
#  'n000144',
#  'n000148',
#  'n000149',
#  'n000154',
#  'n000158',
#  'n000159',
#  'n000160',
#  'n000163',
#  'n000165',
#  'n000171',
#  'n000172',
#  'n000173',
#  'n000178',
#  'n000180',
#  'n000181',
#  'n000182',
#  'n000186',
#  'n000191',
#  'n000192',
#  'n000196',
#  'n000198',
#  'n000205',
#  'n000208',
#  'n000209',
#  'n000210',
#  'n000211',
#  'n000217',
#  'n000220',
#  'n000223',
#  'n000233',
#  'n000235',
#  'n000259',
#  'n000267',
#  'n000276',
#  'n000278',
#  'n000281',
#  'n000284',
#  'n000294',
#  'n000299',
#  'n000318',
#  'n000320',
#  'n000321',
#  'n000322',
#  'n000324',
#  'n000336',
#  'n000337',
#  'n000345',
#  'n000348',
#  'n000352',
#  'n000356',
#  'n000359',
#  'n000363',
#  'n000365',
#  'n000366',
#  'n000370',
#  'n000371',
#  'n000372',
#  'n000378',
#  'n000391',
#  'n000394',
#  'n000410',
#  'n000452',
#  'n000480',
#  'n000527',
#  'n000596',
#  'n000624',
#  'n000654',
#  'n000658',
#  'n000659',
#  'n000667',
#  'n000689',
#  'n000706',
#  'n000736',
#  'n000740',
#  'n000746',
#  'n000774',
#  'n000775',
#  'n000785',
#  'n000836',
#  'n000838',
#  'n000854',
#  'n000912',
#  'n000928',
#  'n000945',
#  'n000950',
#  'n000958',
#  'n000998',
#  'n001021',
#  'n001059',
#  'n001125',
#  'n001127',
#  'n001146',
#  'n001153',
#  'n001156',
#  'n001174',
#  'n001190',
#  'n001197',
#  'n001199',
#  'n001211',
#  'n001242',
#  'n001256',
#  'n001277',
#  'n001291',
#  'n001293',
#  'n001296',
#  'n001299',
#  'n001302',
#  'n001303',
#  'n001304',
#  'n001337',
#  'n001341',
#  'n001368',
#  'n001401',
#  'n001418',
#  'n001439',
#  'n001446',
#  'n001467',
#  'n001485',
#  'n001576',
#  'n001650',
#  'n001655',
#  'n001672',
#  'n001683',
#  'n001687',
#  'n001708',
#  'n001710',
#  'n001781',
#  'n001811',
#  'n001816',
#  'n001817',
#  'n001830',
#  'n001836',
#  'n001838',
#  'n001850',
#  'n001857',
#  'n001878',
#  'n001898',
#  'n001923',
#  'n001934',
#  'n001935',
#  'n001956',
#  'n001976',
#  'n002009',
#  'n002024',
#  'n002080',
#  'n002081',
#  'n002082',
#  'n002093',
#  'n002106',
#  'n002109',
#  'n002153',
#  'n002158',
#  'n002166',
#  'n002167',
#  'n002216',
#  'n002223',
#  'n002245',
#  'n002257',
#  'n002258',
#  'n002263',
#  'n002267',
#  'n002268',
#  'n002282',
#  'n002284',
#  'n002309',
#  'n002329',
#  'n002351',
#  'n002372',
#  'n002381',
#  'n002384',
#  'n002389',
#  'n002414',
#  'n002421',
#  'n002474',
#  'n002475',
#  'n002503',
#  'n002517',
#  'n002556',
#  'n002561',
#  'n002574',
#  'n002581',
#  'n002596',
#  'n002604',
#  'n002647',
#  'n002659',
#  'n002664',
#  'n002669',
#  'n002681',
#  'n002684',
#  'n002703',
#  'n002715',
#  'n002743',
#  'n002749',
#  'n002761',
#  'n002763',
#  'n002770',
#  'n002773',
#  'n002775',
#  'n002803',
#  'n002838',
#  'n002840',
#  'n002855',
#  'n002857',
#  'n002869',
#  'n002873',
#  'n002878',
#  'n002880',
#  'n002884',
#  'n002889',
#  'n002891',
#  'n002894',
#  'n003001',
#  'n003009',
#  'n003079',
#  'n003092',
#  'n003093',
#  'n003104',
#  'n003115',
#  'n003134',
#  'n003140',
#  'n003205',
#  'n003215',
#  'n003217',
#  'n003258',
#  'n003277',
#  'n003288',
#  'n003298',
#  'n003356',
#  'n003379',
#  'n003415',
#  'n003430',
#  'n003436',
#  'n003461',
#  'n003468',
#  'n003490',
#  'n003513',
#  'n003540',
#  'n003554',
#  'n003570',
#  'n003606',
#  'n003635',
#  'n003653',
#  'n003675',
#  'n003725',
#  'n003728',
#  'n003775',
#  'n003786',
#  'n003836',
#  'n003873',
#  'n003881',
#  'n003894',
#  'n003896',
#  'n003917',
#  'n003958',
#  'n004007',
#  'n004050',
#  'n004064',
#  'n004068',
#  'n004070',
#  'n004078',
#  'n004085',
#  'n004123',
#  'n004157',
#  'n004180',
#  'n004208',
#  'n004233',
#  'n004239',
#  'n004240',
#  'n004243',
#  'n004281',
#  'n004333',
#  'n004338',
#  'n004353',
#  'n004357',
#  'n004366',
#  'n004372',
#  'n004380',
#  'n004387',
#  'n004394',
#  'n004411',
#  'n004424',
#  'n004440',
#  'n004449',
#  'n004461',
#  'n004469',
#  'n004482',
#  'n004486',
#  'n004555',
#  'n004563',
#  'n004580',
#  'n004586',
#  'n004588',
#  'n004634',
#  'n004635',
#  'n004652',
#  'n004658',
#  'n004661',
#  'n004662',
#  'n004663',
#  'n004678',
#  'n004679',
#  'n004709',
#  'n004712',
#  'n004719',
#  'n004738',
#  'n004743',
#  'n004756',
#  'n004771',
#  'n004788',
#  'n004793',
#  'n004798',
#  'n004801',
#  'n004812',
#  'n004813',
#  'n004826',
#  'n004850',
#  'n004885',
#  'n004891',
#  'n004898',
#  'n004905',
#  'n004911',
#  'n004915',
#  'n004925',
#  'n004945',
#  'n004999',
#  'n005073',
#  'n005088',
#  'n005101',
#  'n005104',
#  'n005112',
#  'n005114',
#  'n005120',
#  'n005122',
#  'n005123',
#  'n005135',
#  'n005136',
#  'n005137',
#  'n005145',
#  'n005148',
#  'n005157',
#  'n005159',
#  'n005179',
#  'n005181',
#  'n005188',
#  'n005225',
#  'n005226',
#  'n005233',
#  'n005280',
#  'n005282',
#  'n005294',
#  'n005301',
#  'n005303',
#  'n005306',
#  'n005312',
#  'n005316',
#  'n005319',
#  'n005326',
#  'n005328',
#  'n005334',
#  'n005340',
#  'n005347',
#  'n005359',
#  'n005373',
#  'n005377',
#  'n005380',
#  'n005417',
#  'n005425',
#  'n005427',
#  'n005448',
#  'n005473',
#  'n005474',
#  'n005490',
#  'n005513',
#  'n005552',
#  'n005565',
#  'n005577',
#  'n005607',
#  'n005612',
#  'n005619',
#  'n005621',
#  'n005623',
#  'n005630',
#  'n005633',
#  'n005636',
#  'n005639',
#  'n005648',
#  'n005652',
#  'n005664',
#  'n005666',
#  'n005668',
#  'n005670',
#  'n005680',
#  'n005693',
#  'n005695',
#  'n005706',
#  'n005709',
#  'n005723',
#  'n005726',
#  'n005730',
#  'n005748',
#  'n005755',
#  'n005758',
#  'n005762',
#  'n005764',
#  'n005776',
#  'n005799',
#  'n005831',
#  'n005832',
#  'n005833',
#  'n005872',
#  'n005915',
#  'n005956',
#  'n005963',
#  'n005973',
#  'n006053',
#  'n006123',
#  'n006134',
#  'n006211',
#  'n006247',
#  'n006301',
#  'n006347',
#  'n006451',
#  'n006458',
#  'n006497',
#  'n006531',
#  'n006532',
#  'n006574',
#  'n006626',
#  'n006653',
#  'n006659',
#  'n006772',
#  'n006808',
#  'n006858',
#  'n006909',
#  'n006922',
#  'n006987',
#  'n006992',
#  'n007008',
#  'n007021',
#  'n007068',
#  'n007104',
#  'n007121',
#  'n007133',
#  'n007146',
#  'n007159',
#  'n007162',
#  'n007166',
#  'n007169',
#  'n007210',
#  'n007240',
#  'n007241',
#  'n007246',
#  'n007261',
#  'n007296',
#  'n007358',
#  'n007368',
#  'n007381',
#  'n007385',
#  'n007397',
#  'n007439',
#  'n007474',
#  'n007531',
#  'n007548',
#  'n007571',
#  'n007594',
#  'n007650',
#  'n007651',
#  'n007664',
#  'n007668',
#  'n007700',
#  'n007703',
#  'n007753',
#  'n007854',
#  'n007865',
#  'n007900',
#  'n007909',
#  'n007919',
#  'n007949',
#  'n007951',
#  'n008003',
#  'n008015',
#  'n008020',
#  'n008028',
#  'n008036',
#  'n008037',
#  'n008047',
#  'n008056',
#  'n008105',
#  'n008108',
#  'n008110',
#  'n008155',
#  'n008164',
#  'n008179',
#  'n008183',
#  'n008213',
#  'n008314',
#  'n008317',
#  'n008325',
#  'n008361',
#  'n008436',
#  'n008484',
#  'n008488',
#  'n008528',
#  'n008530',
#  'n008539',
#  'n008558',
#  'n008567',
#  'n008595',
#  'n008613',
#  'n008615',
#  'n008630',
#  'n008653',
#  'n008655',
#  'n008662',
#  'n008674',
#  'n008682',
#  'n008710',
#  'n008773',
#  'n008778',
#  'n008829',
#  'n008858',
#  'n008890',
#  'n008932',
#  'n008937',
#  'n008948',
#  'n008958',
#  'n008989',
#  'n009028',
#  'n009114',
#  'n009123',
#  'n009175',
#  'n009185',
#  'n009199',
#  'n009213',
#  'n009225',
#  'n009232',
#  'n009235',
#  'n009283',
#  'n009285',
#  'n009286',
#  'n009287',
#  'n009288',
#  'n009289',
#  'n009291',
#  'n009294']

# %%
label_to_index = dict((name, index) for index,name in enumerate(label_names))
label_to_index
# Out:
# {'n000001': 0,
#  'n000002': 1,
#  'n000003': 2,
#  'n000004': 3,
#  'n000006': 4,
#  'n000007': 5,
#  'n000008': 6,
#  'n000009': 7,
#  'n000010': 8,
#  'n000012': 9,
#  'n000013': 10,
#  'n000015': 11,
#  'n000016': 12,
#  'n000017': 13,
#  'n000018': 14,
#  'n000019': 15,
#  'n000020': 16,
#  'n000029': 17,
#  'n000032': 18,
#  'n000037': 19,
#  'n000040': 20,
#  'n000045': 21,
#  'n000046': 22,
#  'n000056': 23,
#  'n000065': 24,
#  'n000070': 25,
#  'n000074': 26,
#  'n000076': 27,
#  'n000078': 28,
#  'n000079': 29,
#  'n000082': 30,
#  'n000084': 31,
#  'n000088': 32,
#  'n000094': 33,
#  'n000096': 34,
#  'n000104': 35,
#  'n000106': 36,
#  'n000114': 37,
#  'n000118': 38,
#  'n000119': 39,
#  'n000127': 40,
#  'n000129': 41,
#  'n000130': 42,
#  'n000135': 43,
#  'n000144': 44,
#  'n000148': 45,
#  'n000149': 46,
#  'n000154': 47,
#  'n000158': 48,
#  'n000159': 49,
#  'n000160': 50,
#  'n000163': 51,
#  'n000165': 52,
#  'n000171': 53,
#  'n000172': 54,
#  'n000173': 55,
#  'n000178': 56,
#  'n000180': 57,
#  'n000181': 58,
#  'n000182': 59,
#  'n000186': 60,
#  'n000191': 61,
#  'n000192': 62,
#  'n000196': 63,
#  'n000198': 64,
#  'n000205': 65,
#  'n000208': 66,
#  'n000209': 67,
#  'n000210': 68,
#  'n000211': 69,
#  'n000217': 70,
#  'n000220': 71,
#  'n000223': 72,
#  'n000233': 73,
#  'n000235': 74,
#  'n000259': 75,
#  'n000267': 76,
#  'n000276': 77,
#  'n000278': 78,
#  'n000281': 79,
#  'n000284': 80,
#  'n000294': 81,
#  'n000299': 82,
#  'n000318': 83,
#  'n000320': 84,
#  'n000321': 85,
#  'n000322': 86,
#  'n000324': 87,
#  'n000336': 88,
#  'n000337': 89,
#  'n000345': 90,
#  'n000348': 91,
#  'n000352': 92,
#  'n000356': 93,
#  'n000359': 94,
#  'n000363': 95,
#  'n000365': 96,
#  'n000366': 97,
#  'n000370': 98,
#  'n000371': 99,
#  'n000372': 100,
#  'n000378': 101,
#  'n000391': 102,
#  'n000394': 103,
#  'n000410': 104,
#  'n000452': 105,
#  'n000480': 106,
#  'n000527': 107,
#  'n000596': 108,
#  'n000624': 109,
#  'n000654': 110,
#  'n000658': 111,
#  'n000659': 112,
#  'n000667': 113,
#  'n000689': 114,
#  'n000706': 115,
#  'n000736': 116,
#  'n000740': 117,
#  'n000746': 118,
#  'n000774': 119,
#  'n000775': 120,
#  'n000785': 121,
#  'n000836': 122,
#  'n000838': 123,
#  'n000854': 124,
#  'n000912': 125,
#  'n000928': 126,
#  'n000945': 127,
#  'n000950': 128,
#  'n000958': 129,
#  'n000998': 130,
#  'n001021': 131,
#  'n001059': 132,
#  'n001125': 133,
#  'n001127': 134,
#  'n001146': 135,
#  'n001153': 136,
#  'n001156': 137,
#  'n001174': 138,
#  'n001190': 139,
#  'n001197': 140,
#  'n001199': 141,
#  'n001211': 142,
#  'n001242': 143,
#  'n001256': 144,
#  'n001277': 145,
#  'n001291': 146,
#  'n001293': 147,
#  'n001296': 148,
#  'n001299': 149,
#  'n001302': 150,
#  'n001303': 151,
#  'n001304': 152,
#  'n001337': 153,
#  'n001341': 154,
#  'n001368': 155,
#  'n001401': 156,
#  'n001418': 157,
#  'n001439': 158,
#  'n001446': 159,
#  'n001467': 160,
#  'n001485': 161,
#  'n001576': 162,
#  'n001650': 163,
#  'n001655': 164,
#  'n001672': 165,
#  'n001683': 166,
#  'n001687': 167,
#  'n001708': 168,
#  'n001710': 169,
#  'n001781': 170,
#  'n001811': 171,
#  'n001816': 172,
#  'n001817': 173,
#  'n001830': 174,
#  'n001836': 175,
#  'n001838': 176,
#  'n001850': 177,
#  'n001857': 178,
#  'n001878': 179,
#  'n001898': 180,
#  'n001923': 181,
#  'n001934': 182,
#  'n001935': 183,
#  'n001956': 184,
#  'n001976': 185,
#  'n002009': 186,
#  'n002024': 187,
#  'n002080': 188,
#  'n002081': 189,
#  'n002082': 190,
#  'n002093': 191,
#  'n002106': 192,
#  'n002109': 193,
#  'n002153': 194,
#  'n002158': 195,
#  'n002166': 196,
#  'n002167': 197,
#  'n002216': 198,
#  'n002223': 199,
#  'n002245': 200,
#  'n002257': 201,
#  'n002258': 202,
#  'n002263': 203,
#  'n002267': 204,
#  'n002268': 205,
#  'n002282': 206,
#  'n002284': 207,
#  'n002309': 208,
#  'n002329': 209,
#  'n002351': 210,
#  'n002372': 211,
#  'n002381': 212,
#  'n002384': 213,
#  'n002389': 214,
#  'n002414': 215,
#  'n002421': 216,
#  'n002474': 217,
#  'n002475': 218,
#  'n002503': 219,
#  'n002517': 220,
#  'n002556': 221,
#  'n002561': 222,
#  'n002574': 223,
#  'n002581': 224,
#  'n002596': 225,
#  'n002604': 226,
#  'n002647': 227,
#  'n002659': 228,
#  'n002664': 229,
#  'n002669': 230,
#  'n002681': 231,
#  'n002684': 232,
#  'n002703': 233,
#  'n002715': 234,
#  'n002743': 235,
#  'n002749': 236,
#  'n002761': 237,
#  'n002763': 238,
#  'n002770': 239,
#  'n002773': 240,
#  'n002775': 241,
#  'n002803': 242,
#  'n002838': 243,
#  'n002840': 244,
#  'n002855': 245,
#  'n002857': 246,
#  'n002869': 247,
#  'n002873': 248,
#  'n002878': 249,
#  'n002880': 250,
#  'n002884': 251,
#  'n002889': 252,
#  'n002891': 253,
#  'n002894': 254,
#  'n003001': 255,
#  'n003009': 256,
#  'n003079': 257,
#  'n003092': 258,
#  'n003093': 259,
#  'n003104': 260,
#  'n003115': 261,
#  'n003134': 262,
#  'n003140': 263,
#  'n003205': 264,
#  'n003215': 265,
#  'n003217': 266,
#  'n003258': 267,
#  'n003277': 268,
#  'n003288': 269,
#  'n003298': 270,
#  'n003356': 271,
#  'n003379': 272,
#  'n003415': 273,
#  'n003430': 274,
#  'n003436': 275,
#  'n003461': 276,
#  'n003468': 277,
#  'n003490': 278,
#  'n003513': 279,
#  'n003540': 280,
#  'n003554': 281,
#  'n003570': 282,
#  'n003606': 283,
#  'n003635': 284,
#  'n003653': 285,
#  'n003675': 286,
#  'n003725': 287,
#  'n003728': 288,
#  'n003775': 289,
#  'n003786': 290,
#  'n003836': 291,
#  'n003873': 292,
#  'n003881': 293,
#  'n003894': 294,
#  'n003896': 295,
#  'n003917': 296,
#  'n003958': 297,
#  'n004007': 298,
#  'n004050': 299,
#  'n004064': 300,
#  'n004068': 301,
#  'n004070': 302,
#  'n004078': 303,
#  'n004085': 304,
#  'n004123': 305,
#  'n004157': 306,
#  'n004180': 307,
#  'n004208': 308,
#  'n004233': 309,
#  'n004239': 310,
#  'n004240': 311,
#  'n004243': 312,
#  'n004281': 313,
#  'n004333': 314,
#  'n004338': 315,
#  'n004353': 316,
#  'n004357': 317,
#  'n004366': 318,
#  'n004372': 319,
#  'n004380': 320,
#  'n004387': 321,
#  'n004394': 322,
#  'n004411': 323,
#  'n004424': 324,
#  'n004440': 325,
#  'n004449': 326,
#  'n004461': 327,
#  'n004469': 328,
#  'n004482': 329,
#  'n004486': 330,
#  'n004555': 331,
#  'n004563': 332,
#  'n004580': 333,
#  'n004586': 334,
#  'n004588': 335,
#  'n004634': 336,
#  'n004635': 337,
#  'n004652': 338,
#  'n004658': 339,
#  'n004661': 340,
#  'n004662': 341,
#  'n004663': 342,
#  'n004678': 343,
#  'n004679': 344,
#  'n004709': 345,
#  'n004712': 346,
#  'n004719': 347,
#  'n004738': 348,
#  'n004743': 349,
#  'n004756': 350,
#  'n004771': 351,
#  'n004788': 352,
#  'n004793': 353,
#  'n004798': 354,
#  'n004801': 355,
#  'n004812': 356,
#  'n004813': 357,
#  'n004826': 358,
#  'n004850': 359,
#  'n004885': 360,
#  'n004891': 361,
#  'n004898': 362,
#  'n004905': 363,
#  'n004911': 364,
#  'n004915': 365,
#  'n004925': 366,
#  'n004945': 367,
#  'n004999': 368,
#  'n005073': 369,
#  'n005088': 370,
#  'n005101': 371,
#  'n005104': 372,
#  'n005112': 373,
#  'n005114': 374,
#  'n005120': 375,
#  'n005122': 376,
#  'n005123': 377,
#  'n005135': 378,
#  'n005136': 379,
#  'n005137': 380,
#  'n005145': 381,
#  'n005148': 382,
#  'n005157': 383,
#  'n005159': 384,
#  'n005179': 385,
#  'n005181': 386,
#  'n005188': 387,
#  'n005225': 388,
#  'n005226': 389,
#  'n005233': 390,
#  'n005280': 391,
#  'n005282': 392,
#  'n005294': 393,
#  'n005301': 394,
#  'n005303': 395,
#  'n005306': 396,
#  'n005312': 397,
#  'n005316': 398,
#  'n005319': 399,
#  'n005326': 400,
#  'n005328': 401,
#  'n005334': 402,
#  'n005340': 403,
#  'n005347': 404,
#  'n005359': 405,
#  'n005373': 406,
#  'n005377': 407,
#  'n005380': 408,
#  'n005417': 409,
#  'n005425': 410,
#  'n005427': 411,
#  'n005448': 412,
#  'n005473': 413,
#  'n005474': 414,
#  'n005490': 415,
#  'n005513': 416,
#  'n005552': 417,
#  'n005565': 418,
#  'n005577': 419,
#  'n005607': 420,
#  'n005612': 421,
#  'n005619': 422,
#  'n005621': 423,
#  'n005623': 424,
#  'n005630': 425,
#  'n005633': 426,
#  'n005636': 427,
#  'n005639': 428,
#  'n005648': 429,
#  'n005652': 430,
#  'n005664': 431,
#  'n005666': 432,
#  'n005668': 433,
#  'n005670': 434,
#  'n005680': 435,
#  'n005693': 436,
#  'n005695': 437,
#  'n005706': 438,
#  'n005709': 439,
#  'n005723': 440,
#  'n005726': 441,
#  'n005730': 442,
#  'n005748': 443,
#  'n005755': 444,
#  'n005758': 445,
#  'n005762': 446,
#  'n005764': 447,
#  'n005776': 448,
#  'n005799': 449,
#  'n005831': 450,
#  'n005832': 451,
#  'n005833': 452,
#  'n005872': 453,
#  'n005915': 454,
#  'n005956': 455,
#  'n005963': 456,
#  'n005973': 457,
#  'n006053': 458,
#  'n006123': 459,
#  'n006134': 460,
#  'n006211': 461,
#  'n006247': 462,
#  'n006301': 463,
#  'n006347': 464,
#  'n006451': 465,
#  'n006458': 466,
#  'n006497': 467,
#  'n006531': 468,
#  'n006532': 469,
#  'n006574': 470,
#  'n006626': 471,
#  'n006653': 472,
#  'n006659': 473,
#  'n006772': 474,
#  'n006808': 475,
#  'n006858': 476,
#  'n006909': 477,
#  'n006922': 478,
#  'n006987': 479,
#  'n006992': 480,
#  'n007008': 481,
#  'n007021': 482,
#  'n007068': 483,
#  'n007104': 484,
#  'n007121': 485,
#  'n007133': 486,
#  'n007146': 487,
#  'n007159': 488,
#  'n007162': 489,
#  'n007166': 490,
#  'n007169': 491,
#  'n007210': 492,
#  'n007240': 493,
#  'n007241': 494,
#  'n007246': 495,
#  'n007261': 496,
#  'n007296': 497,
#  'n007358': 498,
#  'n007368': 499,
#  'n007381': 500,
#  'n007385': 501,
#  'n007397': 502,
#  'n007439': 503,
#  'n007474': 504,
#  'n007531': 505,
#  'n007548': 506,
#  'n007571': 507,
#  'n007594': 508,
#  'n007650': 509,
#  'n007651': 510,
#  'n007664': 511,
#  'n007668': 512,
#  'n007700': 513,
#  'n007703': 514,
#  'n007753': 515,
#  'n007854': 516,
#  'n007865': 517,
#  'n007900': 518,
#  'n007909': 519,
#  'n007919': 520,
#  'n007949': 521,
#  'n007951': 522,
#  'n008003': 523,
#  'n008015': 524,
#  'n008020': 525,
#  'n008028': 526,
#  'n008036': 527,
#  'n008037': 528,
#  'n008047': 529,
#  'n008056': 530,
#  'n008105': 531,
#  'n008108': 532,
#  'n008110': 533,
#  'n008155': 534,
#  'n008164': 535,
#  'n008179': 536,
#  'n008183': 537,
#  'n008213': 538,
#  'n008314': 539,
#  'n008317': 540,
#  'n008325': 541,
#  'n008361': 542,
#  'n008436': 543,
#  'n008484': 544,
#  'n008488': 545,
#  'n008528': 546,
#  'n008530': 547,
#  'n008539': 548,
#  'n008558': 549,
#  'n008567': 550,
#  'n008595': 551,
#  'n008613': 552,
#  'n008615': 553,
#  'n008630': 554,
#  'n008653': 555,
#  'n008655': 556,
#  'n008662': 557,
#  'n008674': 558,
#  'n008682': 559,
#  'n008710': 560,
#  'n008773': 561,
#  'n008778': 562,
#  'n008829': 563,
#  'n008858': 564,
#  'n008890': 565,
#  'n008932': 566,
#  'n008937': 567,
#  'n008948': 568,
#  'n008958': 569,
#  'n008989': 570,
#  'n009028': 571,
#  'n009114': 572,
#  'n009123': 573,
#  'n009175': 574,
#  'n009185': 575,
#  'n009199': 576,
#  'n009213': 577,
#  'n009225': 578,
#  'n009232': 579,
#  'n009235': 580,
#  'n009283': 581,
#  'n009285': 582,
#  'n009286': 583,
#  'n009287': 584,
#  'n009288': 585,
#  'n009289': 586,
#  'n009291': 587,
#  'n009294': 588}

# %%
index_to_label = dict((index,name) for index,name in enumerate(label_names))
index_to_label
# Out:
# {0: 'n000001',
#  1: 'n000002',
#  2: 'n000003',
#  3: 'n000004',
#  4: 'n000006',
#  5: 'n000007',
#  6: 'n000008',
#  7: 'n000009',
#  8: 'n000010',
#  9: 'n000012',
#  10: 'n000013',
#  11: 'n000015',
#  12: 'n000016',
#  13: 'n000017',
#  14: 'n000018',
#  15: 'n000019',
#  16: 'n000020',
#  17: 'n000029',
#  18: 'n000032',
#  19: 'n000037',
#  20: 'n000040',
#  21: 'n000045',
#  22: 'n000046',
#  23: 'n000056',
#  24: 'n000065',
#  25: 'n000070',
#  26: 'n000074',
#  27: 'n000076',
#  28: 'n000078',
#  29: 'n000079',
#  30: 'n000082',
#  31: 'n000084',
#  32: 'n000088',
#  33: 'n000094',
#  34: 'n000096',
#  35: 'n000104',
#  36: 'n000106',
#  37: 'n000114',
#  38: 'n000118',
#  39: 'n000119',
#  40: 'n000127',
#  41: 'n000129',
#  42: 'n000130',
#  43: 'n000135',
#  44: 'n000144',
#  45: 'n000148',
#  46: 'n000149',
#  47: 'n000154',
#  48: 'n000158',
#  49: 'n000159',
#  50: 'n000160',
#  51: 'n000163',
#  52: 'n000165',
#  53: 'n000171',
#  54: 'n000172',
#  55: 'n000173',
#  56: 'n000178',
#  57: 'n000180',
#  58: 'n000181',
#  59: 'n000182',
#  60: 'n000186',
#  61: 'n000191',
#  62: 'n000192',
#  63: 'n000196',
#  64: 'n000198',
#  65: 'n000205',
#  66: 'n000208',
#  67: 'n000209',
#  68: 'n000210',
#  69: 'n000211',
#  70: 'n000217',
#  71: 'n000220',
#  72: 'n000223',
#  73: 'n000233',
#  74: 'n000235',
#  75: 'n000259',
#  76: 'n000267',
#  77: 'n000276',
#  78: 'n000278',
#  79: 'n000281',
#  80: 'n000284',
#  81: 'n000294',
#  82: 'n000299',
#  83: 'n000318',
#  84: 'n000320',
#  85: 'n000321',
#  86: 'n000322',
#  87: 'n000324',
#  88: 'n000336',
#  89: 'n000337',
#  90: 'n000345',
#  91: 'n000348',
#  92: 'n000352',
#  93: 'n000356',
#  94: 'n000359',
#  95: 'n000363',
#  96: 'n000365',
#  97: 'n000366',
#  98: 'n000370',
#  99: 'n000371',
#  100: 'n000372',
#  101: 'n000378',
#  102: 'n000391',
#  103: 'n000394',
#  104: 'n000410',
#  105: 'n000452',
#  106: 'n000480',
#  107: 'n000527',
#  108: 'n000596',
#  109: 'n000624',
#  110: 'n000654',
#  111: 'n000658',
#  112: 'n000659',
#  113: 'n000667',
#  114: 'n000689',
#  115: 'n000706',
#  116: 'n000736',
#  117: 'n000740',
#  118: 'n000746',
#  119: 'n000774',
#  120: 'n000775',
#  121: 'n000785',
#  122: 'n000836',
#  123: 'n000838',
#  124: 'n000854',
#  125: 'n000912',
#  126: 'n000928',
#  127: 'n000945',
#  128: 'n000950',
#  129: 'n000958',
#  130: 'n000998',
#  131: 'n001021',
#  132: 'n001059',
#  133: 'n001125',
#  134: 'n001127',
#  135: 'n001146',
#  136: 'n001153',
#  137: 'n001156',
#  138: 'n001174',
#  139: 'n001190',
#  140: 'n001197',
#  141: 'n001199',
#  142: 'n001211',
#  143: 'n001242',
#  144: 'n001256',
#  145: 'n001277',
#  146: 'n001291',
#  147: 'n001293',
#  148: 'n001296',
#  149: 'n001299',
#  150: 'n001302',
#  151: 'n001303',
#  152: 'n001304',
#  153: 'n001337',
#  154: 'n001341',
#  155: 'n001368',
#  156: 'n001401',
#  157: 'n001418',
#  158: 'n001439',
#  159: 'n001446',
#  160: 'n001467',
#  161: 'n001485',
#  162: 'n001576',
#  163: 'n001650',
#  164: 'n001655',
#  165: 'n001672',
#  166: 'n001683',
#  167: 'n001687',
#  168: 'n001708',
#  169: 'n001710',
#  170: 'n001781',
#  171: 'n001811',
#  172: 'n001816',
#  173: 'n001817',
#  174: 'n001830',
#  175: 'n001836',
#  176: 'n001838',
#  177: 'n001850',
#  178: 'n001857',
#  179: 'n001878',
#  180: 'n001898',
#  181: 'n001923',
#  182: 'n001934',
#  183: 'n001935',
#  184: 'n001956',
#  185: 'n001976',
#  186: 'n002009',
#  187: 'n002024',
#  188: 'n002080',
#  189: 'n002081',
#  190: 'n002082',
#  191: 'n002093',
#  192: 'n002106',
#  193: 'n002109',
#  194: 'n002153',
#  195: 'n002158',
#  196: 'n002166',
#  197: 'n002167',
#  198: 'n002216',
#  199: 'n002223',
#  200: 'n002245',
#  201: 'n002257',
#  202: 'n002258',
#  203: 'n002263',
#  204: 'n002267',
#  205: 'n002268',
#  206: 'n002282',
#  207: 'n002284',
#  208: 'n002309',
#  209: 'n002329',
#  210: 'n002351',
#  211: 'n002372',
#  212: 'n002381',
#  213: 'n002384',
#  214: 'n002389',
#  215: 'n002414',
#  216: 'n002421',
#  217: 'n002474',
#  218: 'n002475',
#  219: 'n002503',
#  220: 'n002517',
#  221: 'n002556',
#  222: 'n002561',
#  223: 'n002574',
#  224: 'n002581',
#  225: 'n002596',
#  226: 'n002604',
#  227: 'n002647',
#  228: 'n002659',
#  229: 'n002664',
#  230: 'n002669',
#  231: 'n002681',
#  232: 'n002684',
#  233: 'n002703',
#  234: 'n002715',
#  235: 'n002743',
#  236: 'n002749',
#  237: 'n002761',
#  238: 'n002763',
#  239: 'n002770',
#  240: 'n002773',
#  241: 'n002775',
#  242: 'n002803',
#  243: 'n002838',
#  244: 'n002840',
#  245: 'n002855',
#  246: 'n002857',
#  247: 'n002869',
#  248: 'n002873',
#  249: 'n002878',
#  250: 'n002880',
#  251: 'n002884',
#  252: 'n002889',
#  253: 'n002891',
#  254: 'n002894',
#  255: 'n003001',
#  256: 'n003009',
#  257: 'n003079',
#  258: 'n003092',
#  259: 'n003093',
#  260: 'n003104',
#  261: 'n003115',
#  262: 'n003134',
#  263: 'n003140',
#  264: 'n003205',
#  265: 'n003215',
#  266: 'n003217',
#  267: 'n003258',
#  268: 'n003277',
#  269: 'n003288',
#  270: 'n003298',
#  271: 'n003356',
#  272: 'n003379',
#  273: 'n003415',
#  274: 'n003430',
#  275: 'n003436',
#  276: 'n003461',
#  277: 'n003468',
#  278: 'n003490',
#  279: 'n003513',
#  280: 'n003540',
#  281: 'n003554',
#  282: 'n003570',
#  283: 'n003606',
#  284: 'n003635',
#  285: 'n003653',
#  286: 'n003675',
#  287: 'n003725',
#  288: 'n003728',
#  289: 'n003775',
#  290: 'n003786',
#  291: 'n003836',
#  292: 'n003873',
#  293: 'n003881',
#  294: 'n003894',
#  295: 'n003896',
#  296: 'n003917',
#  297: 'n003958',
#  298: 'n004007',
#  299: 'n004050',
#  300: 'n004064',
#  301: 'n004068',
#  302: 'n004070',
#  303: 'n004078',
#  304: 'n004085',
#  305: 'n004123',
#  306: 'n004157',
#  307: 'n004180',
#  308: 'n004208',
#  309: 'n004233',
#  310: 'n004239',
#  311: 'n004240',
#  312: 'n004243',
#  313: 'n004281',
#  314: 'n004333',
#  315: 'n004338',
#  316: 'n004353',
#  317: 'n004357',
#  318: 'n004366',
#  319: 'n004372',
#  320: 'n004380',
#  321: 'n004387',
#  322: 'n004394',
#  323: 'n004411',
#  324: 'n004424',
#  325: 'n004440',
#  326: 'n004449',
#  327: 'n004461',
#  328: 'n004469',
#  329: 'n004482',
#  330: 'n004486',
#  331: 'n004555',
#  332: 'n004563',
#  333: 'n004580',
#  334: 'n004586',
#  335: 'n004588',
#  336: 'n004634',
#  337: 'n004635',
#  338: 'n004652',
#  339: 'n004658',
#  340: 'n004661',
#  341: 'n004662',
#  342: 'n004663',
#  343: 'n004678',
#  344: 'n004679',
#  345: 'n004709',
#  346: 'n004712',
#  347: 'n004719',
#  348: 'n004738',
#  349: 'n004743',
#  350: 'n004756',
#  351: 'n004771',
#  352: 'n004788',
#  353: 'n004793',
#  354: 'n004798',
#  355: 'n004801',
#  356: 'n004812',
#  357: 'n004813',
#  358: 'n004826',
#  359: 'n004850',
#  360: 'n004885',
#  361: 'n004891',
#  362: 'n004898',
#  363: 'n004905',
#  364: 'n004911',
#  365: 'n004915',
#  366: 'n004925',
#  367: 'n004945',
#  368: 'n004999',
#  369: 'n005073',
#  370: 'n005088',
#  371: 'n005101',
#  372: 'n005104',
#  373: 'n005112',
#  374: 'n005114',
#  375: 'n005120',
#  376: 'n005122',
#  377: 'n005123',
#  378: 'n005135',
#  379: 'n005136',
#  380: 'n005137',
#  381: 'n005145',
#  382: 'n005148',
#  383: 'n005157',
#  384: 'n005159',
#  385: 'n005179',
#  386: 'n005181',
#  387: 'n005188',
#  388: 'n005225',
#  389: 'n005226',
#  390: 'n005233',
#  391: 'n005280',
#  392: 'n005282',
#  393: 'n005294',
#  394: 'n005301',
#  395: 'n005303',
#  396: 'n005306',
#  397: 'n005312',
#  398: 'n005316',
#  399: 'n005319',
#  400: 'n005326',
#  401: 'n005328',
#  402: 'n005334',
#  403: 'n005340',
#  404: 'n005347',
#  405: 'n005359',
#  406: 'n005373',
#  407: 'n005377',
#  408: 'n005380',
#  409: 'n005417',
#  410: 'n005425',
#  411: 'n005427',
#  412: 'n005448',
#  413: 'n005473',
#  414: 'n005474',
#  415: 'n005490',
#  416: 'n005513',
#  417: 'n005552',
#  418: 'n005565',
#  419: 'n005577',
#  420: 'n005607',
#  421: 'n005612',
#  422: 'n005619',
#  423: 'n005621',
#  424: 'n005623',
#  425: 'n005630',
#  426: 'n005633',
#  427: 'n005636',
#  428: 'n005639',
#  429: 'n005648',
#  430: 'n005652',
#  431: 'n005664',
#  432: 'n005666',
#  433: 'n005668',
#  434: 'n005670',
#  435: 'n005680',
#  436: 'n005693',
#  437: 'n005695',
#  438: 'n005706',
#  439: 'n005709',
#  440: 'n005723',
#  441: 'n005726',
#  442: 'n005730',
#  443: 'n005748',
#  444: 'n005755',
#  445: 'n005758',
#  446: 'n005762',
#  447: 'n005764',
#  448: 'n005776',
#  449: 'n005799',
#  450: 'n005831',
#  451: 'n005832',
#  452: 'n005833',
#  453: 'n005872',
#  454: 'n005915',
#  455: 'n005956',
#  456: 'n005963',
#  457: 'n005973',
#  458: 'n006053',
#  459: 'n006123',
#  460: 'n006134',
#  461: 'n006211',
#  462: 'n006247',
#  463: 'n006301',
#  464: 'n006347',
#  465: 'n006451',
#  466: 'n006458',
#  467: 'n006497',
#  468: 'n006531',
#  469: 'n006532',
#  470: 'n006574',
#  471: 'n006626',
#  472: 'n006653',
#  473: 'n006659',
#  474: 'n006772',
#  475: 'n006808',
#  476: 'n006858',
#  477: 'n006909',
#  478: 'n006922',
#  479: 'n006987',
#  480: 'n006992',
#  481: 'n007008',
#  482: 'n007021',
#  483: 'n007068',
#  484: 'n007104',
#  485: 'n007121',
#  486: 'n007133',
#  487: 'n007146',
#  488: 'n007159',
#  489: 'n007162',
#  490: 'n007166',
#  491: 'n007169',
#  492: 'n007210',
#  493: 'n007240',
#  494: 'n007241',
#  495: 'n007246',
#  496: 'n007261',
#  497: 'n007296',
#  498: 'n007358',
#  499: 'n007368',
#  500: 'n007381',
#  501: 'n007385',
#  502: 'n007397',
#  503: 'n007439',
#  504: 'n007474',
#  505: 'n007531',
#  506: 'n007548',
#  507: 'n007571',
#  508: 'n007594',
#  509: 'n007650',
#  510: 'n007651',
#  511: 'n007664',
#  512: 'n007668',
#  513: 'n007700',
#  514: 'n007703',
#  515: 'n007753',
#  516: 'n007854',
#  517: 'n007865',
#  518: 'n007900',
#  519: 'n007909',
#  520: 'n007919',
#  521: 'n007949',
#  522: 'n007951',
#  523: 'n008003',
#  524: 'n008015',
#  525: 'n008020',
#  526: 'n008028',
#  527: 'n008036',
#  528: 'n008037',
#  529: 'n008047',
#  530: 'n008056',
#  531: 'n008105',
#  532: 'n008108',
#  533: 'n008110',
#  534: 'n008155',
#  535: 'n008164',
#  536: 'n008179',
#  537: 'n008183',
#  538: 'n008213',
#  539: 'n008314',
#  540: 'n008317',
#  541: 'n008325',
#  542: 'n008361',
#  543: 'n008436',
#  544: 'n008484',
#  545: 'n008488',
#  546: 'n008528',
#  547: 'n008530',
#  548: 'n008539',
#  549: 'n008558',
#  550: 'n008567',
#  551: 'n008595',
#  552: 'n008613',
#  553: 'n008615',
#  554: 'n008630',
#  555: 'n008653',
#  556: 'n008655',
#  557: 'n008662',
#  558: 'n008674',
#  559: 'n008682',
#  560: 'n008710',
#  561: 'n008773',
#  562: 'n008778',
#  563: 'n008829',
#  564: 'n008858',
#  565: 'n008890',
#  566: 'n008932',
#  567: 'n008937',
#  568: 'n008948',
#  569: 'n008958',
#  570: 'n008989',
#  571: 'n009028',
#  572: 'n009114',
#  573: 'n009123',
#  574: 'n009175',
#  575: 'n009185',
#  576: 'n009199',
#  577: 'n009213',
#  578: 'n009225',
#  579: 'n009232',
#  580: 'n009235',
#  581: 'n009283',
#  582: 'n009285',
#  583: 'n009286',
#  584: 'n009287',
#  585: 'n009288',
#  586: 'n009289',
#  587: 'n009291',
#  588: 'n009294'}

# %%
all_train_image_labels = [label_to_index[pathlib.Path(path).parent.name]
                    for path in all_train_image_paths]

print("First 10 labels indices: ", all_train_image_labels[:10])
# Out:
# First 10 labels indices:  [279, 51, 236, 440, 294, 128, 54, 387, 75, 124]

# %%
all_test_image_labels = [label_to_index[pathlib.Path(path).parent.name]
                    for path in all_test_image_paths]

print("First 10 labels indices: ", all_test_image_labels[:10])
# Out:
# First 10 labels indices:  [543, 554, 520, 502, 505, 524, 478, 494, 564, 564]

# %%
def load_positive_path_match(label_index, img_path1, base="data\\processed2\\images2\\"):
    label = index_to_label[label_index]
    dir_path = base+label
    img_path2 = dir_path+'\\'+random.choice(os.listdir(dir_path))
    return label_index, img_path1, label_index, img_path2

# %%
def load_random_path_match(label_index1, img_path1, dirs, base="data\\processed2\\images2\\"):
    random_dir = random.choice(dirs)
    label = random_dir.split('\\')[-1]
    label_index = label_to_index[label]
    dir_files = os.listdir(random_dir)
    if len(dir_files) != 0:
        random_file = random.choice(dir_files)
        while '.jpg' not in random_file:
            #print('redo random.choice(dir_files) : ', random_dir)
            random_file = random.choice(dir_files)
        img_path2 = random_dir+'\\'+random_file
        return label_index1, img_path1, label_index, img_path2
    else:
        return '', '', '', ''

# %%
img_path1 = all_train_image_paths[0]
label_index = all_train_image_labels[0]
load_random_path_match(label_index, img_path1, image_dir_paths_train)
# Out:
# (279,
#  'data\\processed2\\images2\\n003513\\0286_01.jpg',
#  9,
#  'data\\processed2\\images2\\n000012\\0265_01.jpg')

# %%
img_path1 = all_train_image_paths[0]
label_index = all_train_image_labels[0]
load_positive_path_match(label_index, img_path1)
# Out:
# (279,
#  'data\\processed2\\images2\\n003513\\0286_01.jpg',
#  279,
#  'data\\processed2\\images2\\n003513\\0331_01.jpg')

# %%
all_train_image_paths[0]
# Out:
# 'data\\processed2\\images2\\n003513\\0286_01.jpg'

# %%
all_train_image_labels[0]
# Out:
# 279

# %%
all_train_image_pair_paths = []
all_train_image_pair_labels = []
all_train_data_labels = []

for label_index, image_path in tqdm.tqdm(zip(all_train_image_labels, all_train_image_paths), total=len(all_train_image_labels)):
    choice = random.choice([0,1])
    if choice == 0:
        label_index1, img_path1, label_index2, img_path2 = load_random_path_match(label_index, image_path, image_dir_paths_train)
        all_train_image_pair_paths.append((img_path1, img_path2))
        all_train_image_pair_labels.append((label_index1, label_index2))
        if label_index1 == '' or label_index2 == '':
            continue
        if label_index1 == label_index2:
            all_train_data_labels.append(1)
        else:
            all_train_data_labels.append(0)
    else:
        label_index1, img_path1, label_index2, img_path2 = load_positive_path_match(label_index, image_path)
        all_train_image_pair_paths.append((img_path1, img_path2))
        all_train_image_pair_labels.append((label_index1, label_index2))
        if label_index1 == label_index2:
            all_train_data_labels.append(1)
        else:
            all_train_data_labels.append(0)


len(all_train_image_pair_paths), len(all_train_image_pair_labels), len(all_train_data_labels)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 149186/149186 [00:33<00:00, 4491.28it/s]
# (149186, 149186, 149186)

# %%
all_train_image_pair_paths[:5], all_train_image_pair_labels[:5], all_train_data_labels[:10]
# Out:
# ([('data\\processed2\\images2\\n003513\\0286_01.jpg',
#    'data\\processed2\\images2\\n003513\\0199_01.jpg'),
#   ('data\\processed2\\images2\\n000163\\0158_01.jpg',
#    'data\\processed2\\images2\\n006574\\0441_01.jpg'),
#   ('data\\processed2\\images2\\n002749\\0257_01.jpg',
#    'data\\processed2\\images2\\n002749\\0156_01.jpg'),
#   ('data\\processed2\\images2\\n005723\\0072_01.jpg',
#    'data\\processed2\\images2\\n000337\\0203_01.jpg'),
#   ('data\\processed2\\images2\\n003894\\0222_02.jpg',
#    'data\\processed2\\images2\\n000208\\0395_01.jpg')],
#  [(279, 279), (51, 470), (236, 236), (440, 89), (294, 66)],
#  [1, 0, 1, 0, 0, 0, 1, 1, 1, 1])

# %%
a, b = list(zip(*all_train_image_pair_paths[:5]))
a
# Out:
# ('data\\processed2\\images2\\n003513\\0286_01.jpg',
#  'data\\processed2\\images2\\n000163\\0158_01.jpg',
#  'data\\processed2\\images2\\n002749\\0257_01.jpg',
#  'data\\processed2\\images2\\n005723\\0072_01.jpg',
#  'data\\processed2\\images2\\n003894\\0222_02.jpg')

# %%
all_test_image_pair_paths = []
all_test_image_pair_labels = []
all_test_data_labels = []

for label_index, image_path in tqdm.tqdm(zip(all_test_image_labels, all_test_image_paths), total=len(all_test_image_labels)):
    choice = random.choice([0,1])
    if choice == 0:
        label_index1, img_path1, label_index2, img_path2 = load_random_path_match(label_index, image_path, image_dir_paths_test)
        all_test_image_pair_paths.append((img_path1, img_path2))
        all_test_image_pair_labels.append((label_index1, label_index2))
        if label_index1 == label_index2:
            all_test_data_labels.append(1)
        else:
            all_test_data_labels.append(0)
    else:
        label_index1, img_path1, label_index2, img_path2 = load_positive_path_match(label_index, image_path)
        all_test_image_pair_paths.append((img_path1, img_path2))
        all_test_image_pair_labels.append((label_index1, label_index2))
        if label_index1 == label_index2:
            all_test_data_labels.append(1)
        else:
            all_test_data_labels.append(0)

len(all_test_image_pair_paths), len(all_test_image_pair_labels), len(all_test_data_labels)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 30030/30030 [00:06<00:00, 4660.31it/s]
# (30030, 30030, 30030)

# %%
all_test_image_pair_paths[:5], all_test_image_pair_labels[:5], all_test_data_labels[:10]
# Out:
# ([('data\\processed2\\images2\\n008436\\0197_01.jpg',
#    'data\\processed2\\images2\\n008436\\0213_01.jpg'),
#   ('data\\processed2\\images2\\n008630\\0377_01.jpg',
#    'data\\processed2\\images2\\n008630\\0358_08.jpg'),
#   ('data\\processed2\\images2\\n007919\\0555_01.jpg',
#    'data\\processed2\\images2\\n007919\\0214_01.jpg'),
#   ('data\\processed2\\images2\\n007397\\0006_01.jpg',
#    'data\\processed2\\images2\\n007397\\0216_01.jpg'),
#   ('data\\processed2\\images2\\n007531\\0424_01.jpg',
#    'data\\processed2\\images2\\n007700\\0162_01.jpg')],
#  [(543, 543), (554, 554), (520, 520), (502, 502), (505, 513)],
#  [1, 1, 1, 1, 0, 0, 0, 1, 0, 1])

# %%
def preprocess_image(path):
    image = tf.read_file(path)
    
    image = tf.image.decode_jpeg(image, channels=3)

    return image

# %%
def load_and_preprocess_image(paths):
#     paths = tf.constant(np.array(list(paths)))
    return tf.map_fn(preprocess_image, paths)

# %%
import matplotlib.pyplot as plt


img_paths = all_train_image_pair_paths[0]
label_indexs = all_train_image_pair_labels[0]
image1, image2 = preprocess_image(img_paths[0]), preprocess_image(img_paths[1])
plt.subplot(2,2,1)
plt.imshow(image1)
plt.title(label_names[label_index].title())


plt.subplot(2,2,2)
plt.imshow(image2)

plt.grid(False)
plt.title(label_names[label_index].title())
print()

# %%
label_indexs
# Out:
# (279, 279)

# %%
input_shape = m.input_shape[1:]

# %%
input_shape
# Out:
# (160, 160, 3)

# %%
for layer in m.layers[:-6]:
    layer.trainable = False

# %%
def squared_differences(pair_of_tensors):
    x, y = pair_of_tensors
    return k.square(x - y)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Lambda, add, Dropout, BatchNormalization

inputs1 = Input(input_shape)
inputs2 = Input(input_shape)
x1 = m(inputs1)
x2 = m(inputs2)
x1 = Model(inputs = inputs1, outputs = x1)
x2 = Model(inputs = inputs2, outputs = x2)


x = Lambda(squared_differences)([x1.output, x2.output])
X = BatchNormalization()(X)
X = Dense(4, activation = tf.nn.relu)(x)
X = Dropout(rate=0.25)(X)
X = BatchNormalization()(X)
 #x= Dropout(0.5)(X)
output = Dense(1, activation = 'sigmoid')(x)

# %%
model = Model(inputs =[x1.input,x2.input], outputs=output)
model.compile(
    optimizer = tf.keras.optimizers.Adam(0.001), 
    loss = 'binary_crossentropy', 
    metrics = ["accuracy"],
)

# %%
all_train_image_pair_paths_a, all_train_image_pair_paths_b = list(zip(*all_train_image_pair_paths))
all_train_image_pair_paths_a = list(all_train_image_pair_paths_a)
all_train_image_pair_paths_b = list(all_train_image_pair_paths_b)

# %%
path_ds_a = tf.data.Dataset.from_tensor_slices(all_train_image_pair_paths_a)
path_ds_b = tf.data.Dataset.from_tensor_slices(all_train_image_pair_paths_b)

type(path_ds_a)
# Out:
# tensorflow.python.data.ops.dataset_ops.DatasetV1Adapter

# %%
train_image_datasource_a = path_ds_a.map(preprocess_image, num_parallel_calls=AUTOTUNE)
train_image_datasource_b = path_ds_b.map(preprocess_image, num_parallel_calls=AUTOTUNE)
train_image_datasource = tf.data.Dataset.zip((train_image_datasource_a, train_image_datasource_b))

# %%
train_label_datasource = tf.data.Dataset.from_tensor_slices(tf.cast(all_train_data_labels, tf.int64))

# %%
train_datasource = tf.data.Dataset.zip((train_image_datasource, train_label_datasource))

# %%
all_test_image_pair_paths_a, all_test_image_pair_paths_b = list(zip(*all_test_image_pair_paths))
all_test_image_pair_paths_a = list(all_test_image_pair_paths_a)
all_test_image_pair_paths_b = list(all_test_image_pair_paths_b)

# %%
test_path_ds_a = tf.data.Dataset.from_tensor_slices(all_test_image_pair_paths_a)
test_path_ds_b = tf.data.Dataset.from_tensor_slices(all_test_image_pair_paths_b)

type(test_path_ds_a)
# Out:
# tensorflow.python.data.ops.dataset_ops.DatasetV1Adapter

# %%
test_image_datasource_a = test_path_ds_a.map(preprocess_image, num_parallel_calls=AUTOTUNE)
test_image_datasource_b = test_path_ds_b.map(preprocess_image, num_parallel_calls=AUTOTUNE)
test_image_datasource = tf.data.Dataset.zip((test_image_datasource_a, test_image_datasource_b))

# %%
test_label_datasource = tf.data.Dataset.from_tensor_slices(tf.cast(all_test_data_labels, tf.int64))

# %%
test_datasource = tf.data.Dataset.zip((test_image_datasource, test_label_datasource))

# %%
# train_datasource = train_datasource.shuffle(buffer_size=1000)

# %%
train_datasource = train_datasource.repeat()

# %%
train_datasource = train_datasource.batch(BATCH_SIZE)

# %%
train_datasource = train_datasource.prefetch(buffer_size=AUTOTUNE)

# %%
# test_datasource = test_datasource.shuffle(buffer_size=1000)

# %%
test_datasource = test_datasource.repeat()

# %%
test_datasource = test_datasource.batch(BATCH_SIZE)

# %%
test_datasource = test_datasource.prefetch(buffer_size=AUTOTUNE)

# %%
int(len(all_test_image_pair_paths)/BATCH_SIZE)
# Out:
# 938

# %%
callbacks = [
  # Interrupt training if `val_loss` stops improving for over 2 epochs
  #tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss'),
  # Write TensorBoard logs to `./logs` directory
  tf.keras.callbacks.TensorBoard(log_dir='./logs')
]
model.fit(train_datasource, epochs=100, callbacks = callbacks, steps_per_epoch=int(len(all_train_image_pair_paths)/BATCH_SIZE),
          validation_data=test_datasource, 
          validation_steps=int(len(all_test_image_pair_paths)/BATCH_SIZE))
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\engine\training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, **kwargs)
#     230           training_utils.make_logs(model, val_results, mode, prefix='val_'))
#     231
# --> 232     callbacks.on_epoch_end(epoch, epoch_logs, mode=mode)
#     233     progbar.on_epoch_end(epoch, epoch_logs)
#     234   callbacks._call_end_hook(mode)
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs, mode)
#     249       logs = logs or {}
#     250       for callback in self.callbacks:
# --> 251         callback.on_epoch_end(epoch, logs)
#     252
#     253   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#    1157     else:
#    1158       step = self._samples_seen
# -> 1159     self._write_custom_summaries(step, logs)
#    1160
#    1161     # pop the histogram summary op after each epoch
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\callbacks.py in _write_custom_summaries(self, step, logs)
#    1104           if isinstance(value, np.ndarray):
#    1105             value = value.item()
# -> 1106           summary_ops_v2.scalar(name, value, step=step)
#    1107     else:
#    1108       # use FileWriter from v1 summary
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py in scalar(name, tensor, family, step)
#     562         name=scope)
#     563
# --> 564   return summary_writer_function(name, tensor, function, family=family)
#     565
#     566
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py in summary_writer_function(name, tensor, function, family)
#     506   with ops.device("cpu:0"):
#     507     op = smart_cond.smart_cond(
# --> 508         should_record_summaries(), record, _nothing, name="")
#     509     if not context.executing_eagerly():
#     510       ops.add_to_collection(ops.GraphKeys._SUMMARY_COLLECTION, op)  # pylint: disable=protected-access
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      52   if pred_value is not None:
#      53     if pred_value:
# ---> 54       return true_fn()
#      55     else:
#      56       return false_fn()
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py in record()
#     499     with ops.name_scope(name_scope), summary_op_util.summary_scope(
#     500         name, family, values=[tensor]) as (tag, scope):
# --> 501       with ops.control_dependencies([function(tag, scope)]):
#     502         return constant_op.constant(True)
#     503
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py in function(tag, scope)
#     560         tag,
#     561         array_ops.identity(tensor),
# --> 562         name=scope)
#     563
#     564   return summary_writer_function(name, tensor, function, family=family)
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\gen_summary_ops.py in write_scalar_summary(writer, step, tag, value, name)
#     673       try:
#     674         return write_scalar_summary_eager_fallback(
# --> 675             writer, step, tag, value, name=name, ctx=_ctx)
#     676       except _core._SymbolicException:
#     677         pass  # Add nodes to the TensorFlow graph.
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\ops\gen_summary_ops.py in write_scalar_summary_eager_fallback(writer, step, tag, value, name, ctx)
#     704   _attrs = ("T", _attr_T)
#     705   _result = _execute.execute(b"WriteScalarSummary", 0, inputs=_inputs_flat,
# --> 706                              attrs=_attrs, ctx=_ctx, name=name)
#     707   _result = None
#     708   return _result
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      64     else:
#      65       message = e.message
# ---> 66     six.raise_from(core._status_to_exception(e.code, message), None)
#      67   except TypeError as e:
#      68     if any(ops._is_keras_symbolic_tensor(x) for x in inputs):
#
# c:\users\user\anaconda3\envs\tf_gpu\lib\site-packages\six.py in raise_from(value, from_value)
#
# UnknownError: The events file ./logs/events.out.tfevents.1568557149.LAPTOP-PNH1L90C.v2 has disappeared.
# 	Failed to flush 1 events to ./logs/events.out.tfevents.1568557149.LAPTOP-PNH1L90C.v2
# 	Could not flush events file. [Op:WriteScalarSummary] name: epoch_loss/

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(0.01), 
    loss = 'binary_crossentropy', 
    metrics = ["accuracy"],
)
