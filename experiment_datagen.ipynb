# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from VisionUtils import *
import numpy
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
os.listdir("demo/database/pics")
# Out:
# ['April.jpg',
#  'betsy.jpg',
#  'face_dude.jpg',
#  'JAKE.jpg',
#  'jovi.jpg',
#  'tyrel.jpg']

# %%
img = plt.imread("demo/database/pics/April.jpg")

# %%
plt.imshow(img)

# %% [markdown]
# datagen = ImageDataGenerator(
#             rotation_range = [30, 10])

# %% [markdown]
# im1 = datagen.random_transform(img)

# %%
im1 = add_parallel_light("demo/database/pics/April.jpg")
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)
# Out:
# Rotate degree:  271

# %%
# %matplotlib inline
plt.imshow(im1)

# %%
im1 = add_spot_light("demo/database/pics/April.jpg")
im1 = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)

# %%
# %matplotlib inline
plt.imshow(im1)

# %%
import imageio
import imgaug as ia
# %matplotlib inline

image = imageio.imread("https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png")

print("Original:")
ia.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-fddad67effc8> in <module>
#       1 import imageio
# ----> 2 import imgaug as ia
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4
#       5 image = imageio.imread("https://upload.wikimedia.org/wikipedia/en/7/7d/Lenna_%28test_image%29.png")
#
# ModuleNotFoundError: No module named 'imgaug'

# %%
from imgaug import augmenters as iaa
import imgaug as ia


img = plt.imread("demo/database/pics/April.jpg")
ia.seed(4)

rotate = iaa.Affine(rotate=(-25, 25))
image_aug = rotate.augment_image(image)

print("Augmented:")
ia.imshow(image_aug)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-e0fe2d987199> in <module>
#       1
# ----> 2 from imgaug import augmenters as iaa
#       3 import imgaug as ia
#       4
#       5
#
# ModuleNotFoundError: No module named 'imgaug'
