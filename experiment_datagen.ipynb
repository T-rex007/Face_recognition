# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from VisionUtils import *
from imgaug import augmenters as iaa
import numpy
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import cv2
import imgaug

# %%
m = MTCNN()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0831 23:26:16.795878 10092 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\mtcnn.py:187: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0831 23:26:16.820273 10092 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\mtcnn.py:193: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0831 23:26:16.871206 10092 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\network.py:43: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0831 23:26:16.871206 10092 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:88: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
os.listdir("demo/database/pics")
# Out:
# ['April.jpg',
#  'betsy.jpg',
#  'face_dude.jpg',
#  'JAKE.jpg',
#  'jovi.jpg',
#  'tyrel.jpg']

# %%
img = plt.imread("demo/database/pics/.jpg")

# %%
plt.imshow(img)

# %%
bb = detect_faces(img, m)
imcrop = crop_face(img, bb[0])

# %%
#seq = iaa.Sequential([iaa.CLAHE(clip_limit = 4)])
seq = iaa.Sequential([iaa.GaussianBlur(sigma = .)])
im_aug = seq.augment_images(imcrop)

# %%
plt.imshow(imcrop)

# %%
plt.imshow(im_aug)

# %%
#img_aug = add_spot_light(img)
#img_aug = add_spot_light(img_aug)

# %%
VID_PATH = "demo/database/outpy.avi"
import cv2
VID_PATH = "demo/database/outpy.avi"
cap = cv2.VideoCapture(VID_PATH)
m = MTCNN()
font = cv2.FONT_HERSHEY_SIMPLEX
while(cap.isOpened()):
    ### Capture Videos
    ret, frame = cap.read()
    frame = cv2.resize(frame, (600, 600))
    break
    #frame = im_aug = seq.augment_images(frame)
    #frame = increase_brightness(frame)
    
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    cv2.imshow('videos', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
plt.imshow(frame)
