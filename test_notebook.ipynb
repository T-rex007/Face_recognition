# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import model_from_json, load_model
from mtcnn.mtcnn import MTCNN
from pathlib import Path as path
import json
from PIL import ImageDraw, ImageFont
from matplotlib import patches, patheffects
import pdb ### Python debuger
import os ### Navigate Through Dirrectory
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import collections
import cv2
from utils import *

# %%
model = load_model("Models/FaceNet/facenet_keras.h5")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0706 22:09:10.406671  4768 hdf5_format.py:221] No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
class ImageManager:
    ### Class Constructor
    def __init__(self, feature_extractor, face_detector, imgpaths = None):
        self.imgpaths = imgpaths
        self.feature_extractor = feature_extractor
        self.face_detector = face_detector
        self.bb_lst = []
        self.im_sz = feature_extractor.input_shape
        self.img = None
    def detect_faces(self, img):
        results = self.face_detector.detect_faces(img)
        for i in results:
            self.bb_lst.append(i["box"])
        return bb_lst
    def extract_feature(self, img):
        image_features = 
        for i in range(len(bb_lst)):
            img = crop_face(img, bb_lst[i])
            img = resize(img,(self.im_sz[1],im_sz[2]))
            img = normalize(img).reshape((1, im_sz[1],im_sz[2], im_sz[3]))
            image_features.append(feature_extractor.predict(img))
        return image_features
    

    def normalize(self, img):
        """
        Normalize the image pixels values between  1 and 0
        """
        return img/255
    
    def crop_face(self,img):
        """
        Crop the area delimited by the the bounding box bb
        """
        im_lst = []
        for i in range(len(bb)):
            x1, y1, width, height = bb[i]
            x1,y1 = abs(x1), abs(y1)
            x2, y2 = x1 + width, y1 + height
            im_lst.append(img[y1:y2, x1:x2])
        return im_lst

# %%
dtor = MTCNN()
t = ImageManager(model, dtor,imgpaths= None)
# Out:
# W0706 22:09:10.448634  4768 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\mtcnn.py:187: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0706 22:09:10.448634  4768 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\mtcnn.py:193: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0706 22:09:10.464226  4768 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\network.py:43: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0706 22:09:10.464226  4768 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:88: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0706 22:09:10.464226  4768 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:79: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0706 22:09:10.464226  4768 deprecation.py:506] From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0706 22:09:10.495499  4768 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:171: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0706 22:09:10.554411  4768 deprecation.py:323] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:221: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# W0706 22:09:10.755872  4768 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:196: The name tf.nn.xw_plus_b is deprecated. Please use tf.compat.v1.nn.xw_plus_b instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ade45c632ec8> in <module>
#       1 dtor = MTCNN()
# ----> 2 t = ImageManager(model, dtor,imgpaths= None)
#
# <ipython-input-8-1d99ce777257> in __init__(self, feature_extractor, face_detector, imgpaths)
#       2     ### Class Constructor
#       3     def __init__(self, feature_extractor, face_detector, imgpaths = None):
# ----> 4         tf.enable_eager_execution()
#       5         self.imgpaths = imgpaths
#       6         self.feature_extractor = feature_extractor
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in enable_eager_execution(config, device_policy, execution_mode)
#    5876         device_policy=device_policy,
#    5877         execution_mode=execution_mode,
# -> 5878         server_def=None)
#    5879
#    5880
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in enable_eager_execution_internal(config, device_policy, execution_mode, server_def)
#    5934     if graph_mode_has_been_used:
#    5935       raise ValueError(
# -> 5936           "tf.enable_eager_execution must be called at program startup.")
#    5937   context.default_execution_mode = context.EAGER_MODE
#    5938   # pylint: disable=protected-access
#
# ValueError: tf.enable_eager_execution must be called at program startup.

# %%
timg = plt.imread("pics/t.jpg")

# %%
plt.imshow(cv2.resize(timg, (160, 160)))

# %%
model.input_shape
# Out:
# (None, 160, 160, 3)

# %%
t.resize(timg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-0c261ee558d5> in <module>
# ----> 1 t.resize(timg)
#
# <ipython-input-20-1b7a23c53fd9> in resize(self, img)
#       9         self.img = None
#      10     def resize(self, img):
# ---> 11         tf.enable_eager_execution()
#      12         """
#      13         Returns a Resized Image of with the same shape as the input shape of the feature extractor
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in enable_eager_execution(config, device_policy, execution_mode)
#    5876         device_policy=device_policy,
#    5877         execution_mode=execution_mode,
# -> 5878         server_def=None)
#    5879
#    5880
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in enable_eager_execution_internal(config, device_policy, execution_mode, server_def)
#    5934     if graph_mode_has_been_used:
#    5935       raise ValueError(
# -> 5936           "tf.enable_eager_execution must be called at program startup.")
#    5937   context.default_execution_mode = context.EAGER_MODE
#    5938   # pylint: disable=protected-access
#
# ValueError: tf.enable_eager_execution must be called at program startup.
