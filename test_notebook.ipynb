# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import model_from_json, load_model
from mtcnn.mtcnn import MTCNN
from pathlib import Path as path
import json
from PIL import ImageDraw, ImageFont
from matplotlib import patches, patheffects
import pdb ### Python debuger
import os ### Navigate Through Dirrectory
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import collections
import cv2
from utils import *

# %%
model = load_model("Models/FaceNet/facenet_keras.h5")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0706 22:09:10.406671  4768 hdf5_format.py:221] No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
timg = plt.imread("pics/t.jpg")

# %%
plt.imshow(cv2.resize(timg, (160, 160)))

# %%
model.input_shape
# Out:
# (None, 160, 160, 3)

# %%
dtor =MTCNN()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0709 14:56:48.839887 14548 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\mtcnn.py:187: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0709 14:56:48.865877 14548 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\mtcnn.py:193: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0709 14:56:48.897756 14548 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\network.py:43: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0709 14:56:48.898755 14548 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\lib\site-packages\mtcnn\layer_factory.py:88: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
img = plt.imread("test/n000001/0275_01.jpg")

# %%
plt.imshow(img)
plt.show()

# %%
results = dtor.detect_faces(img)

# %%
results
# Out:
# []
